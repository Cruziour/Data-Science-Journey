# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Creating a DataFrame

# %%
data = {
    'Name': ['Rupesh','Rohan','Sahil','Ravi'],
    'Age': [23,42,23,35],
    'City': ['Hajipur', 'Patna', 'Noida', 'Sitamarhi'],
    'Salary': [25000, 70000, 62000, 85000]
}
df1=pd.DataFrame(data)
df1
# Out:
#      Name  Age       City  Salary
# 0  Rupesh   23    Hajipur   25000
# 1   Rohan   42      Patna   70000
# 2   Sahil   23      Noida   62000
# 3    Ravi   35  Sitamarhi   85000

# %%
data_list = [
    ['Sonal',28,'Jandaha',62000],
    ['Abhi',38,'Arniya',72000],
    ['Raushan',42,'Salha',63000],
    ['Sonal',58,'Pirapur',92000],
]
columns = ['Name', 'Age', 'City', 'Salary']

# %%
df2=pd.DataFrame(data_list, columns=columns)
df2
# Out:
#       Name  Age     City  Salary
# 0    Sonal   28  Jandaha   62000
# 1     Abhi   38   Arniya   72000
# 2  Raushan   42    Salha   63000
# 3    Sonal   58  Pirapur   92000

# %% [markdown]
# ### Selection and Indexing of column

# %%
df2['Name']
# Out:
# 0      Sonal
# 1       Abhi
# 2    Raushan
# 3      Sonal
# Name: Name, dtype: str

# %%
df2['City']
# Out:
# 0    Jandaha
# 1     Arniya
# 2      Salha
# 3    Pirapur
# Name: City, dtype: str

# %%
df1[['Name','City']]
# Out:
#      Name       City
# 0  Rupesh    Hajipur
# 1   Rohan      Patna
# 2   Sahil      Noida
# 3    Ravi  Sitamarhi

# %% [markdown]
# ### Creating a new column

# %%
df2['Designation']= ["Doctor","Eng","Doctor","Eng"]

# %%
df2
# Out:
#       Name  Age     City  Salary Designation
# 0    Sonal   28  Jandaha   62000      Doctor
# 1     Abhi   38   Arniya   72000         Eng
# 2  Raushan   42    Salha   63000      Doctor
# 3    Sonal   58  Pirapur   92000         Eng

# %% [markdown]
# ### Removing Column

# %% [markdown]
# ### Selecting Rows

# %% [markdown]
# ### Selecting Subsets of rows and columns

# %% [markdown]
# ### Conditional Selection
